# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoprestesmazur-dot/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 1**  🕔  🚛  👽
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**aula 7**  ⏰  ▶  ◀

# %%
import random
dica = [
    "Acredite em você — tudo começa com a sua própria confiança 🌟",
    "Pequenos passos também te levam longe; o importante é não parar 👣",
    "Erros fazem parte do aprendizado — cada falha é uma chance de crescer 📘",
    "Mantenha o foco no que realmente importa e não se distraia com comparações 🎯",
    "Celebre suas conquistas, mesmo as pequenas 🏆",
    "Seja constante, não perfeito 🔁",
    "Cuide da sua mente e do seu corpo — equilíbrio é essencial 🧘‍♂️",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
  elif pedido == "sair":
    print("até a próxima! \n")
    break
  else:
    print("omando inválido. tente novmente. \n")
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-899978412.py in <cell line: 0>()
#      10 ]
#      11 while True:
# ---> 12   pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()
#      13
#      14   if pedido == "dica":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
ano = "IX"
print(ano, " competição de programação dá Start")
# Out:
# IX  competição de programação dá Start

# %% [markdown]
# #**aula 2** ⏰  ⚡  ☕

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana

# %% [markdown]
# #**aula 3**   🚛  ⏰  🫀

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
# Out:
# Digite o total de figurinhas: 6
# Digite o número de amigos: 0

# %% [markdown]
# #**aula 4**  ✈ ⏫  👾

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# #**aula 5**  ◀  ◀  ◀

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 8
# 8 x 1 = 8.0
# 8 x 2 = 4.0
# 8 x 3 = 2.6666666666666665
# 8 x 4 = 2.0
# 8 x 5 = 1.6
# 8 x 6 = 1.3333333333333333
# 8 x 7 = 1.1428571428571428
# 8 x 8 = 1.0
# 8 x 9 = 0.8888888888888888
# 8 x 10 = 0.8

# %% [markdown]
# #**aula 6**  ⚓  ▶  ⏰

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python!")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática!")
else:
    print(f" Que pena, {nome}, não sei falar dess assunto")
